# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy
plt.rc('xtick',labelsize=8) #set axis text size
plt.rc('ytick',labelsize=10)
df = pd.read_csv (r'C:\Users\user\Desktop\Dataset\Book1.csv')   #read the csv file (put 'r' before the path string to address any special characters in the path, such as '\'). Don't forget to put the file name at the end of the path + ".csv"
a = df['Point'].values  #point
b = df['Total'].values #Total
c = df['New'].values  #New
d = df['Date'].values  #Date
plt.plot(d,b,'ro-', label='line 1', linewidth=1) #linewidth is width of the graph line
plt.xlabel('Month')
plt.ylabel('Total Cases')
plt.title('Graph for Active Cases')
plt.show()

plt.plot(d,c,'go-', label='line 1', linewidth=2)
plt.xlabel('Month')
plt.ylabel('New Active Cases')
plt.title('Graph for New Cases per day')
plt.show()


# Python3 Program to interpolate using 
# newton forward interpolation 

# calculating u mentioned in the formula 
def u_cal(u, n): 

	temp = u; 
	for i in range(1, n): 
		temp = temp * (u - i); 
	return temp; 

# calculating factorial of given number n 
def fact(n): 
	f = 1; 
	for i in range(2, n + 1): 
		f *= i; 
	return f; 

# Driver Code 

# Number of values given 
n = a.size; 
x = a

#print(a.size)
#print(b.size)

# y[][] is used for difference table 
# with y[][0] used for input 
y = [[0 for i in range(n)] 
		for j in range(n)]; 
for i in range (0,b.size-1):
    y[i][0]=b[i] 

# Calculating the forward difference 
# table 
for i in range(1, n): 
	for j in range(n - i): 
		y[j][i] = y[j + 1][i - 1] - y[j][i - 1]; 

 
# Value to interpolate at 
value = 

# initializing u and sum 
sum = y[0][0]; 
u = (value - x[0]) / (x[1] - x[0]); 
for i in range(1,n): 
	sum = sum + (u_cal(u, i) * y[0][i]) / fact(i); 

print("\nValue at", value,"is", sum); 

# This code is contributed by mits 


#dataset: https://github.com/owid/covid-19-data/tree/master/public/data
# Out:
# Value at 7.5 is -2289092.0
