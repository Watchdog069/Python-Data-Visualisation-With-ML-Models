# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes='true')
# %matplotlib inline
iris=sns.load_dataset('iris')
iris.head()
sns.pairplot(iris, hue='species',size=3,aspect=1)
iris.hist(edgecolor='black', linewidth=1.2, figsize=(12,10))
plt.show()
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.violinplot(x='species',y='sepal_length',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='species',y='sepal_width',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='species',y='petal_length',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='species',y='petal_width',data=iris)
iris.boxplot(by='species',figsize=(12,8))
pd.plotting.scatter_matrix(iris,figsize=(12,8))
plt.show()
# Out:
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
