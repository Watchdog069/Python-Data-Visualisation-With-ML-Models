# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
df = pd.read_csv (r'C:\Users\user\Desktop\Dataset\bmi.csv')   #read the csv file (put 'r' before the path string to address any special characters in the path, such as '\'). Don't forget to put the file name at the end of the path + ".csv"
a = df['Height'].values  #height
b = df['Weight'].values #weight
c = df['Index'].values #index
d = df['Gender'].values #gender

def dist(x2,x1,y2,y1):
    return math.sqrt((x2-x1)*(x2-x1)+(y2-y1)*(y2-y1))

print('red-zero,green-one,blue-two,cyan-three,magenta-four,yellow-five')
#male BMI scatter
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
male=0
female=0
i=0
while(i<c.size):
    if(c[i]==0 and d[i]=='Male'):
        ax.scatter(b[i], a[i], color='r')
        male=male+1
    i=i+1
i=0    
while(i<c.size):
    if(c[i]==1 and d[i]=='Male'):
        ax.scatter(b[i], a[i], color='g')
        male=male+1
    i=i+1
i=0    
while(i<c.size):
    if(c[i]==2 and d[i]=='Male'):
        ax.scatter(b[i], a[i], color='b')
        male=male+1
    i=i+1
i=0    
while(i<c.size):
    if(c[i]==3 and d[i]=='Male'):
        ax.scatter(b[i], a[i], color='c')
        male=male+1
    i=i+1
i=0    
while(i<c.size):
    if(c[i]==4 and d[i]=='Male'):
        ax.scatter(b[i], a[i], color='y')
        male=male+1
    i=i+1
i=0    
while(i<c.size):
    if(c[i]==5 and d[i]=='Male'):
        ax.scatter(b[i], a[i], color='m')
        male=male+1
    i=i+1    
    
ax.set_xlabel('Weight(kg)')
ax.set_ylabel('Height(cm)')
ax.set_title('Male BMI scatter plot') 
   
    
#knn test point
ax.scatter(124,173,color='k')

#method1
testcount=0
i=0
one=0
two=0
three=0
four=0
five=0
zero=0
print('\nMale Scatter knn test: Method1, rectangular')
while(i<c.size):
    if((d[i]=='Male') and (b[i]>115 and b[i]<135 and a[i]>163 and a[i]<183)):
        testcount=testcount+1
        if(c[i]==0):
            zero=zero+1
        elif(c[i]==1):
            one=one+1
        elif(c[i]==2):
            two=two+1
        elif(c[i]==3):
            three=three+1
        elif(c[i]==4):
            four=four+1
        else:
            five=five+1
    i=i+1    
print('Total Neighbouring points=k=',testcount,'\nzero:',zero,', one:',one,', two:',two,', three:',three,', four:',four,', five:',five)        

#method2
testcount=0
i=0
one=0
two=0
three=0
four=0
five=0
zero=0
print('\nMale Scatter knn test: Method2, circle')
while(i<c.size):
    if((d[i]=='Male') and dist(x1=b[i],x2=124,y1=a[i],y2=173)<10):
        testcount=testcount+1
        if(c[i]==0):
            zero=zero+1
        elif(c[i]==1):
            one=one+1
        elif(c[i]==2):
            two=two+1
        elif(c[i]==3):
            three=three+1
        elif(c[i]==4):
            four=four+1
        else:
            five=five+1
    i=i+1    
print('Total Neighbouring points=k=',testcount,'\nzero:',zero,', one:',one,', two:',two,', three:',three,', four:',four,', five:',five)        

plt.rc('xtick',labelsize=10) #set axis text size
plt.rc('ytick',labelsize=10)
plt.show() 
    

    
    

#female BMI scatter.
import matplotlib.pyplot as plt1
fig1=plt1.figure()
ax1=fig1.add_axes([0,0,1,1])

i=0
while(i<c.size):
    if(c[i]==0 and d[i]=='Female'):
        ax1.scatter(b[i], a[i], color='r')
        female=female+1
    i=i+1
i=0    
while(i<c.size):
    if(c[i]==1 and d[i]=='Female'):
        ax1.scatter(b[i], a[i], color='g')
        female=female+1
    i=i+1
i=0    
while(i<c.size):
    if(c[i]==2 and d[i]=='Female'):
        ax1.scatter(b[i], a[i], color='b')
        female=female+1
    i=i+1
i=0    
while(i<c.size):
    if(c[i]==3 and d[i]=='Female'):
        ax1.scatter(b[i], a[i], color='c')
        female=female+1
    i=i+1
i=0    
while(i<c.size):
    if(c[i]==4 and d[i]=='Female'):
        ax1.scatter(b[i], a[i], color='y')
        female=female+1
    i=i+1
i=0    
while(i<c.size):
    if(c[i]==5 and d[i]=='Female'):
        ax1.scatter(b[i], a[i], color='m')
        female=female+1
    i=i+1    
 
ax1.set_xlabel('Weight(kg)')
ax1.set_ylabel('Height(cm)')
ax1.set_title('Female BMI scatter plot')    
plt1.rc('xtick',labelsize=10) #set axis text size
plt1.rc('ytick',labelsize=10)
plt1.show()


#male female ratio
fper=(female/a.size)*100
mper=(male/a.size)*100
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Female', 'Male'
sizes = [fper,mper]
explode = (0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.set_title('Male Female Ratio')
plt.show()
# Out:
# red-zero,green-one,blue-two,cyan-three,magenta-four,yellow-five
#
# Male Scatter knn test: Method1, rectangular
# Total Neighbouring points=k= 9
# zero: 0 , one: 0 , two: 0 , three: 0 , four: 5 , five: 4
#
# Male Scatter knn test: Method2, circle
# Total Neighbouring points=k= 10
# zero: 0 , one: 0 , two: 0 , three: 0 , four: 6 , five: 4
